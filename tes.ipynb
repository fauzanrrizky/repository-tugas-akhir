# %%
import pickle

# %%
# Membuka file .pkl
with open('train_large (1).pkl', 'rb') as file:
    data = pickle.load(file)

# Menampilkan data yang di-load
data
# Out:
#                                                  name_1  \
# 0                                                RDECOM
# 1                                                   YPO
# 2                                                  FLAC
# 3                                                   TAM
# 4     FORWARD ARMING AND REFUELLING POINT / FORWARD ...
# ...                                                 ...
# 5995                                                MVR
# 5996                                                HHD
# 5997  ANIMA SANA IN CORPORE SANO (LATIN, "A SOUND MI...
# 5998           GAUSS - GENERAL AUDIENCES (MOVIE RATING)
# 5999  AIR DEFENCE - ANDORRA (ISO 3166 DIGRAM) - ANNO...
#
#                                                  name_2  y
# 0     (U.S. ARMY) RESEARCH, DEVELOPMENT AND ENGINEER...  1
# 1                                                   PLL  0
# 2                                                    J3  0
# ...

# %%
data.to_excel('./data/train_large.xlsx', index=False)
