# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 7M+ Dataset

# %%
df = pd.read_csv('../data/companies_sorted.csv')

# %%
df
# Out:
#          Unnamed: 0                            name  \
# 0           5872184                             ibm
# 1           4425416       tata consultancy services
# 2             21074                       accenture
# 3           2309813                         us army
# 4           1558607                              ey
# ...             ...                             ...
# 7173421     1494427              certiport vouchers
# 7173422     1494429          black tiger fight club
# 7173423     4768462      catholic bishop of chicago
# 7173424     1494436             medexo robotics ltd
# 7173425     2842728  dynamic controls solutions inc
#
#                                domain  year founded  \
# 0                             ibm.com        1911.0
# 1                             tcs.com        1968.0
# 2                       accenture.com        1989.0
# 3                          goarmy.com        1800.0
# 4                              ey.com        1989.0
# ...

# %%
countries = ['united states', 'germany', 'india', 'united kingdom', 'france', 'russia', 'canada', 'italy', 'brazil', 'australia', 'mexico', 'spain', 'indonesia', 'netherlands']

# %%
country_counts = df['country'].value_counts().head(20)
# Plot a pie chart
plt.figure(figsize=(8, 6))
plt.pie(country_counts, labels=country_counts.index, autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title('Top 5 Country Count')
plt.show()

# %%
country_counts_20 = df['country'].value_counts().head(20)
country_counts_20
# Out:
# country
# united states     2278866
# united kingdom     511969
# canada             186621
# india              144444
# spain              143941
# netherlands        136809
# germany            118575
# australia          117133
# france             114706
# italy              109818
# brazil             108382
# belgium             47581
# china               36548
# turkey              35350
# sweden              34942
# mexico              33701
# switzerland         32742
# denmark             29213
# south africa        26631
# norway              25936
# Name: count, dtype: int64

# %%
df_idn_count = df[df['country'] == "indonesia"].shape[0]
df_idn_count
# Out:
# 14938

# %% [markdown]
# ## TO Excel

# %%
# df_idn.to_excel('../data/indonesia_companies_7m.xlsx', index=False)
